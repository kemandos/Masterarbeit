# %%
# This code is importing various libraries that will be used in the SkillExtractor class. 
# The FutureWarning and DeprecationWarning libraries are being imported so that the user can ignore warnings that might come up. The SkillExtractor class will be used to extract skills from a given text.


import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning) 
import pandas as pd
from tqdm import tqdm_notebook
import spacy
from spacy.matcher import PhraseMatcher
# load default skills data base
from skillNer.general_params import SKILL_DB
# import skill extractor
from skillNer.skill_extractor_class import SkillExtractor
# init params of skill extractor
nlp = spacy.load("en_core_web_lg")
# init skill extractor
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher)
import ast
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
from nltk.tokenize.treebank import TreebankWordDetokenizer
# Out:
# loading full_matcher ...
# loading abv_matcher ...
# loading full_uni_matcher ...
# loading low_form_matcher ...
# loading token_matcher ...

# %%
# This code reads in an Excel file from a specified location
# and stores it in a pandas DataFrame called "df"
# The DataFrame is then sorted by the "text_id" column

# read_excel(): pandas function for reading in Excel files
# sort_values(): pandas function for sorting DataFrames


df = pd.read_excel('Master/04_Analysis/04_01_custom_analysis/04_01_02_tableau_data/01_tableau_base_data_geocoded.xlsx')
df = df.sort_values(by=['text_id'])
df.head(5)
# Out:
#    text_id                                           jobTitle            role  \
# 0        1  department head data management data warehouse...   data engineer
# 1        2  accumulation data analyst in accumulation and ...    data analyst
# 2        3  accumulation data engineer in accumulation and...   data engineer
# 3        4                           actuarial data scientist  data scientist
# 4        5                    actuarial data scientist actuar  data scientist
#
#   level                                     jobDescription  \
# 0  head  location is flexible job purpose the role is f...
# 1   mid  data engineer join us let care for tomorrow at...
# 2   mid  join us let care for tomorrow at allianz globa...
# 3   mid  we take responsibility for the sustainable man...
# 4   mid  hirschau central full time about us conrad con...
#
#                                   Company             Industry       city  \
# 0    dfv deutsche familienversicherung ag       versicherungen  Frankfurt
# 1    allianz global corporate & specialty       versicherungen    München
# 2    allianz global corporate & specialty       versicherungen    München
# 3                   verti versicherung ag  finanzdienstleister     Teltow
# 4  concordia versicherungsgesellschaft ag       versicherungen   Hannover
#
#          lat       long          state state_code      country country_code
# 0  50.110644   8.682092         Bayern         BY  Deutschland           de
# 1  48.137108  11.575382         Bayern         BY  Deutschland           de
# 2  48.137108  11.575382         Bayern         BY  Deutschland           de
# 3  52.401646  13.264453    Brandenburg         BB  Deutschland           de
# 4  52.374478   9.738553  Niedersachsen         NI  Deutschland           de

# %%
# The first line of code defines a list of stop words, which are words that are commonly used in the English language but don't hold a lot of meaning, such as "the" or "and" etc.
# The second line of code defines a list of characters that should be removed from the job titles, such as punctuation marks and digits. The third line of code defines a function that takes in a dataframe as an argument. 
# This function tokenizes the job titles, which means it splits them up into individual words. It also removes any stop words or punctuation marks. Finally, it detokenizes the job titles, which means it puts them back together into a single string. 
# The fourth line of code applies this function to the dataframe. The fifth line of code prints the number of rows in the dataframe. The sixth line of code prints the first two rows of the dataframe.stop_words = stopwords.words('english')



def tokenazing_job_description(dataframe):

    stop_words = stopwords.words('english')
    to_remove2 = stop_words + list(string.punctuation)
    # lemmatize = nltk.WordNetLemmatizer()
    dataframe['job_desc_token'] = dataframe['jobDescription'].apply(word_tokenize).apply(lambda x: [item for item in x if item not in to_remove2])
    dataframe['job_desc_clean'] = dataframe['job_desc_token'].apply(TreebankWordDetokenizer().detokenize)
    # dataframe['job_desc_clean'] =dataframe.apply(lambda row: lemmatize.lemmatize(row['job_desc_clean']), axis=1)
    return dataframe

    
df = tokenazing_job_description(df)
df.head(5)
# Out:
#    text_id                                           jobTitle            role  \
# 0        1  department head data management data warehouse...   data engineer
# 1        2  accumulation data analyst in accumulation and ...    data analyst
# 2        3  accumulation data engineer in accumulation and...   data engineer
# 3        4                           actuarial data scientist  data scientist
# 4        5                    actuarial data scientist actuar  data scientist
#
#   level                                     jobDescription  \
# 0  head  location is flexible job purpose the role is f...
# 1   mid  data engineer join us let care for tomorrow at...
# 2   mid  join us let care for tomorrow at allianz globa...
# 3   mid  we take responsibility for the sustainable man...
# 4   mid  hirschau central full time about us conrad con...
#
#                                   Company             Industry       city  \
# 0    dfv deutsche familienversicherung ag       versicherungen  Frankfurt
# 1    allianz global corporate & specialty       versicherungen    München
# 2    allianz global corporate & specialty       versicherungen    München
# 3                   verti versicherung ag  finanzdienstleister     Teltow
# 4  concordia versicherungsgesellschaft ag       versicherungen   Hannover
#
#          lat       long          state state_code      country country_code  \
# 0  50.110644   8.682092         Bayern         BY  Deutschland           de
# 1  48.137108  11.575382         Bayern         BY  Deutschland           de
# 2  48.137108  11.575382         Bayern         BY  Deutschland           de
# 3  52.401646  13.264453    Brandenburg         BB  Deutschland           de
# 4  52.374478   9.738553  Niedersachsen         NI  Deutschland           de
#
#                                       job_desc_token  \
# 0  [location, flexible, job, purpose, role, focus...
# 1  [data, engineer, join, us, let, care, tomorrow...
# 2  [join, us, let, care, tomorrow, allianz, globa...
# 3  [take, responsibility, sustainable, management...
# 4  [hirschau, central, full, time, us, conrad, co...
#
#                                       job_desc_clean
# 0  location flexible job purpose role focused add...
# 1  data engineer join us let care tomorrow allian...
# 2  join us let care tomorrow allianz global inves...
# 3  take responsibility sustainable management ene...
# 4  hirschau central full time us conrad conquers ...

# %%
# The code below creates a list from the job descriptions column in the df DataFrame.

job_descriptions_list_full = df['job_desc_clean'].tolist()

# %%
# This code is a function that takes in a list of job descriptions (your_list) and outputs a list of dataframes (data)
# The function loops through each job description in the list (tqdm_notebook(range(len(job_descriptions_list_full))))
# For each job description, the function extracts the skills mentioned using the skill_extractor.annotate() method
# The extracted skills are then converted into a dataframe (skills_found_for_df)
# These dataframes are then appended to the list 'data' which is returned at the end of the function


def process_job_description(your_list):

    data = []
    for i in tqdm_notebook(range(len(job_descriptions_list_full))):
        annotations = skill_extractor.annotate(job_descriptions_list_full[i])
        skill_match = annotations
        skills_found_for_df = pd.io.json.json_normalize(skill_match)
        data.append(skills_found_for_df)
    return data

data_full = process_job_description(job_descriptions_list_full)
# Out:
#   0%|          | 0/2311 [00:00<?, ?it/s]
# c:\Users\Aleksej Aikov\miniconda3\lib\site-packages\skillNer\utils.py:99: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   vec_similarity = token1.similarity(token2)

# %%
# The code concatenates a list of dataframes called "data_full" and stores the result in a new dataframe called "df_exatracted_skills".

# The new dataframe "df_exatracted_skills" is then written to a Parquet file called "04_03_skillner_extracted_skills_final.parquet", with the index set to "False" to prevent the index column from being written to the CSV file.


df_exatracted_skills = pd.concat(data_full)

df_exatracted_skills.to_parquet('Master/04_Analysis/04_03_extracting_skills_with_skillner_ner/04_03_01_skillner_extracted_skills_final.parquet', engine='fastparquet')

# %%
# This code reads in a Parquet file containing  job descriptions to be normalized and displays the first 5 rows.

normalizing_df_full = pd.read_parquet('Master/04_Analysis/04_03_extracting_skills_with_skillner_ner/04_03_01_skillner_extracted_skills_final.parquet')

normalizing_df_full.head(5)
# Out:
#                                                 text  \
# 0  location flexible job purpose role focused add...
# 1  data engineer join us let care tomorrow allian...
# 2  join us let care tomorrow allianz global inves...
# 3  take responsibility sustainable management ene...
# 4  hirschau central full time us conrad conquers ...
#
#                                 results.full_matches  \
# 0  [{'skill_id': 'KS441DK70RM6XLJ3P36X', 'doc_nod...
# 1  [{'skill_id': 'KSWR4RCZQM7RAQNUFC40', 'doc_nod...
# 2  [{'skill_id': 'KSWR4RCZQM7RAQNUFC40', 'doc_nod...
# 3  [{'skill_id': 'KS4413M6FXN7CQ6QF15D', 'doc_nod...
# 4  [{'skill_id': 'KS1261Z68KSKR1X31KS3', 'doc_nod...
#
#                                 results.ngram_scored
# 0  [{'skill_id': 'KS127D361PF0FTXDZ7C4', 'doc_nod...
# 1  [{'skill_id': 'KS122NX79W5LSNS07C02', 'doc_nod...
# 2  [{'skill_id': 'KS1203K780JW14PLP167', 'doc_nod...
# 3  [{'skill_id': 'KS127D361PF0FTXDZ7C4', 'doc_nod...
# 4  [{'skill_id': 'KS1253H61TTR1FZWSRH4', 'doc_nod...

# %%
# The first line of code drops the 'results.ngram_scored' column from the dataframe. The second line drops the 'results.full_matches' column. 
# 
# The third line drops the 'results.ngram_scored' and 'results.full_matches' columns and adds a new column called 'id' with the index values from the original dataframe.

df_full_match = normalizing_df_full.drop(columns=['results.ngram_scored'])
df_ngram_match = normalizing_df_full.drop(columns=['results.full_matches'])
df_text_df =  normalizing_df_full.drop(columns=['results.full_matches', 'results.ngram_scored'])
df_text_df['id'] = normalizing_df_full.index

# %%
# This code defines a function called "union" that takes in two dataframes (df1 and df2) as input. 

# The first dataframe (df1) is modified by renaming the column "results.full_matches" to "match", and then dropping all the rows that have missing values in the "match" column. 
# 
# The "match" column is then converted into a list of literal values, and each value in the list is turned into its own dataframe. These dataframes are then concatenated together, 
# the index is reset, and only the rows with a score of 0.8 or higher are kept. The column "doc_node_value" is then modified by replacing the word "datum" with "data", and the columns "score", "doc_node_id", and "level_1" are dropped. 
# The remaining columns are then renamed to "skill_name" and "id_text", respectively. 

# The second dataframe (df2) is modified in a similar way, except that the column "results.ngram_scored" is renamed to "match", and the column "type" and "len" are dropped. 

# Finally, the two dataframes (df1 and df2) are concatenated together and the resulting dataframe is returned.


def union(df1, df2):

    df1.rename(columns = {'results.full_matches':'match'}, inplace = True)
    df1 = df1['match'].dropna().apply(ast.literal_eval)
    df1 = pd.concat([pd.DataFrame(x) for x in df1], keys=df1.index)
    df1.reset_index(inplace=True)
    df1 = df1.query('score >= 0.8')
    df1['doc_node_value'] = df1['doc_node_value'].str.replace("datum", "data")
    df1 = df1.drop(columns=['score','doc_node_id','level_1'])
    df1 = df1.rename(columns = {'doc_node_value':'skill_name', 'level_0':'id_text'})


    df2.rename(columns = {'results.ngram_scored':'match'}, inplace = True)
    df2 = df2['match'].dropna().apply(ast.literal_eval)
    df2 = pd.concat([pd.DataFrame(x) for x in df2], keys=df2.index)
    df2.reset_index(inplace=True)
    df2['score'] = df2['score'].astype(float)
    df2 = df2.query('score >= 0.8')
    df2 = df2.drop(columns=['score','doc_node_id','type','len','level_1'])
    df2 = df2.rename(columns = {'doc_node_value':'skill_name', 'level_0':'id_text'})

    union  = pd.concat([df1, df2],ignore_index=True)

    return union

# %%
# This code joins together two dataframes, `df_full_match` and `df_ngram_match`, into a new dataframe called `normalized_df_full`. 
# 
# The dataframes are combined by rows, so the new dataframe will have all the rows of `df_full_match`, followed by all the rows of `df_ngram_match`.


normalized_df_full = union(df_full_match, df_ngram_match)
normalized_df_full
# Out:
#        id_text              skill_id            skill_name
# 0            0  KS441DK70RM6XLJ3P36X           time series
# 1            0  KS1206R6J3HDQV8PPC87    operation research
# 2            0  KS1261Z68KSKR1X31KS3         machine learn
# 3            0  KS1219863VWXPRZL5LG2  business requirement
# 4            0  KS1267F6MSPN366LX7ST    project management
# ...        ...                   ...                   ...
# 65419     2310  KS7AASDV6UOE7VFBGF4D         collaborative
# 65420     2310  KSIWWZAII4AP33SDVZ2H                   git
# 65421     2310  KS122PM76DCYL9WC89Y7         data modeling
# 65422     2310  KS121XY6VSGJ3Z6J82FQ       infrastructures
# 65423     2310  KSKJX44T33B6D4UCC8CB              teamwork
#
# [65424 rows x 3 columns]

# %%
# The function takes 2 dataframes, df and df_text.

# It changes the type of the 'id' column in df_text to int.

# Then, it merges df and df_text on the 'id_text' column of df and the 'id' column of df_text.

# The how='left' parameter keeps all the rows from df and only adds rows from df_text that have a match in df.

# The function then drops the 'id' column from the merged dataframe and returns the new dataframe.

# Finally, it assigns the new dataframe to normalized_df_full.


def rejoin_df(df,df_text):
    df_text['id'] = df_text['id'].astype(int)
    df = pd.merge(df, df_text, left_on='id_text', right_on='id', how='left')
    df = df.drop(columns=['id'])
    return df

normalized_df_full = rejoin_df(normalized_df_full,df_text_df)
normalized_df_full
# Out:
#        id_text              skill_id            skill_name  \
# 0            0  KS441DK70RM6XLJ3P36X           time series
# 1            0  KS1206R6J3HDQV8PPC87    operation research
# 2            0  KS1261Z68KSKR1X31KS3         machine learn
# 3            0  KS1219863VWXPRZL5LG2  business requirement
# 4            0  KS1267F6MSPN366LX7ST    project management
# ...        ...                   ...                   ...
# 65419     2310  KS7AASDV6UOE7VFBGF4D         collaborative
# 65420     2310  KSIWWZAII4AP33SDVZ2H                   git
# 65421     2310  KS122PM76DCYL9WC89Y7         data modeling
# 65422     2310  KS121XY6VSGJ3Z6J82FQ       infrastructures
# 65423     2310  KSKJX44T33B6D4UCC8CB              teamwork
#
#                                                     text
# 0      location flexible job purpose role focused add...
# 1      location flexible job purpose role focused add...
# 2      location flexible job purpose role focused add...
# 3      location flexible job purpose role focused add...
# 4      location flexible job purpose role focused add...
# ...                                                  ...
# 65419  listed company around million customer contrac...
# 65420  listed company around million customer contrac...
# 65421  listed company around million customer contrac...
# 65422  listed company around million customer contrac...
# 65423  listed company around million customer contrac...
#
# [65424 rows x 4 columns]

# %%
# 1. This code takes a dataframe of normalized skills from a file called 'normalized_df_full' and saves it as a parquet file called 'normalized_df_full_final'

# 2. It then reads in a parquet file called 'normalized_df_full_final' and assigns it to a variable called 'found_skills'

# 3. Finally, it reads in a CSV file called 'enski_skills_db' and assigns it to a variable called 'enski_skills_db'


normalized_df_full.to_parquet('Master/04_Analysis/04_03_extracting_skills_with_skillner_ner/04_03_02_normalized_df_full_final.parquet',engine='fastparquet')
found_skills = pd.read_parquet('Master/04_Analysis/04_03_extracting_skills_with_skillner_ner/04_03_02_normalized_df_full_final.parquet')
enski_skills_db = pd.read_csv('Master/04_Analysis/04_02_ensi_skills_extraction/04_02_ensi_skills_db.csv')

# %%
# Displays the column in enski_skills_db DataFrame

enski_skills_db.columns
# Out:
# Index(['category', 'description', 'descriptionSource', 'id', 'infoUrl',
#        'isLanguage', 'isSoftware', 'name', 'removedDescription', 'subcategory',
#        'tags', 'type.id', 'type.name', 'category.id', 'category.name',
#        'subcategory.id', 'subcategory.name'],
#       dtype='object')

# %%
# Print the first 5 rows in the DataFrame

enski_skills_db.head(5)
# Out:
#    category                                        description  \
# 0       NaN                                                NaN
# 1       NaN  \nDefined by Microsoft for use in recent versi...
# 2       NaN                                                NaN
# 3       NaN  The .NET Framework is a software framework dev...
# 4       NaN  Microsoft started development on the .NET Fram...
#
#                                   descriptionSource                    id  \
# 0                                               NaN  KS120P86XDXZJT3B7KVJ
# 1     https://en.wikipedia.org/wiki/.NET_assemblies  KS126XS6CQCFGC3NG79X
# 2                                               NaN  ES50D03AC9CFC1A0BC93
# 3      https://en.wikipedia.org/wiki/.NET_Framework  KS1200B62W5ZF38RJ7TD
# 4  https://en.wikipedia.org/wiki/.NET_Framework_1.0  KS126XW78QJCF4TRV2X7
#
#                                              infoUrl  isLanguage  isSoftware  \
# 0  https://skills.emsidata.com/skills/KS120P86XDX...       False       False
# 1  https://skills.emsidata.com/skills/KS126XS6CQC...       False        True
# 2  https://skills.emsidata.com/skills/ES50D03AC9C...       False       False
# 3  https://skills.emsidata.com/skills/KS1200B62W5...       False        True
# 4  https://skills.emsidata.com/skills/KS126XW78QJ...       False        True
#
#                                            name  removedDescription  \
# 0  (American Society For Quality) ASQ Certified                 NaN
# 1                               .NET Assemblies                 NaN
# 2                              .NET Development                 NaN
# 3                                .NET Framework                 NaN
# 4                              .NET Framework 1                 NaN
#
#    subcategory                                               tags type.id  \
# 0          NaN                                                 []     ST3
# 1          NaN  [{'key': 'wikipediaExtract', 'value': '\nDefin...     ST1
# 2          NaN  [{'key': 'wikipediaExtract', 'value': 'The .NE...     ST1
# 3          NaN  [{'key': 'wikipediaExtract', 'value': 'The .NE...     ST1
# 4          NaN  [{'key': 'wikipediaExtract', 'value': 'Microso...     ST1
#
#            type.name  category.id           category.name  subcategory.id  \
# 0      Certification          NaN                     NaN             NaN
# 1  Specialized Skill         17.0  Information Technology           442.0
# 2  Specialized Skill         17.0  Information Technology           442.0
# 3  Specialized Skill         17.0  Information Technology           442.0
# 4  Specialized Skill         17.0  Information Technology           442.0
#
#               subcategory.name
# 0                          NaN
# 1  Microsoft Development Tools
# 2  Microsoft Development Tools
# 3  Microsoft Development Tools
# 4  Microsoft Development Tools

# %%
# This code starts by renaming certain columns in the 'enski_skills_db' dataframe. The columns that are renamed are 'id', 'name', 'description', 'category.name', 'subcategory.name', and 'type.name'. The new names for these columns are 'skill_id', 'skill_name', 'skill_description', 'skill_category_name', 'skill_subcategory_name', and 'skill_type_name', respectively. 

# After the columns have been renamed, the first five rows of the dataframe are printed.

enski_skills_db = enski_skills_db.rename(columns={'id': 'skill_id', 'name': 'skill_name', 'description': 'skill_description', 'category.name'	: 'skill_category_name', 'subcategory.name': 'skill_subcategory_name', 'type.name': 'skill_type_name'})
enski_skills_db.head(5)
# Out:
#    category                                  skill_description  \
# 0       NaN                                                NaN
# 1       NaN  \nDefined by Microsoft for use in recent versi...
# 2       NaN                                                NaN
# 3       NaN  The .NET Framework is a software framework dev...
# 4       NaN  Microsoft started development on the .NET Fram...
#
#                                   descriptionSource              skill_id  \
# 0                                               NaN  KS120P86XDXZJT3B7KVJ
# 1     https://en.wikipedia.org/wiki/.NET_assemblies  KS126XS6CQCFGC3NG79X
# 2                                               NaN  ES50D03AC9CFC1A0BC93
# 3      https://en.wikipedia.org/wiki/.NET_Framework  KS1200B62W5ZF38RJ7TD
# 4  https://en.wikipedia.org/wiki/.NET_Framework_1.0  KS126XW78QJCF4TRV2X7
#
#                                              infoUrl  isLanguage  isSoftware  \
# 0  https://skills.emsidata.com/skills/KS120P86XDX...       False       False
# 1  https://skills.emsidata.com/skills/KS126XS6CQC...       False        True
# 2  https://skills.emsidata.com/skills/ES50D03AC9C...       False       False
# 3  https://skills.emsidata.com/skills/KS1200B62W5...       False        True
# 4  https://skills.emsidata.com/skills/KS126XW78QJ...       False        True
#
#                                      skill_name  removedDescription  \
# 0  (American Society For Quality) ASQ Certified                 NaN
# 1                               .NET Assemblies                 NaN
# 2                              .NET Development                 NaN
# 3                                .NET Framework                 NaN
# 4                              .NET Framework 1                 NaN
#
#    subcategory                                               tags type.id  \
# 0          NaN                                                 []     ST3
# 1          NaN  [{'key': 'wikipediaExtract', 'value': '\nDefin...     ST1
# 2          NaN  [{'key': 'wikipediaExtract', 'value': 'The .NE...     ST1
# 3          NaN  [{'key': 'wikipediaExtract', 'value': 'The .NE...     ST1
# 4          NaN  [{'key': 'wikipediaExtract', 'value': 'Microso...     ST1
#
#      skill_type_name  category.id     skill_category_name  subcategory.id  \
# 0      Certification          NaN                     NaN             NaN
# 1  Specialized Skill         17.0  Information Technology           442.0
# 2  Specialized Skill         17.0  Information Technology           442.0
# 3  Specialized Skill         17.0  Information Technology           442.0
# 4  Specialized Skill         17.0  Information Technology           442.0
#
#         skill_subcategory_name
# 0                          NaN
# 1  Microsoft Development Tools
# 2  Microsoft Development Tools
# 3  Microsoft Development Tools
# 4  Microsoft Development Tools

# %%
#1. The function 'drop_columns_ensi_skills' takes in a dataframe as input and drops certain columns from the dataframe.
#2. It then filters the dataframe by removing all rows where the 'skill_category_name' column is null.
#3. Finally, it returns the filtered dataframe.
#4. The variable 'enski_skills_db' is assigned the output of the 'drop_columns_ensi_skills' function applied to the 'enski_skills_db' dataframe.
#5. The first five rows of the resulting dataframe are then printed.


def drop_columns_ensi_skills(df):
    df = df.drop(columns=['category','descriptionSource','removedDescription','tags','subcategory','removedDescription','category.id','subcategory.id','type.id'])
    filtered_df = df[df['skill_category_name'].notnull()]

    return filtered_df
enski_skills_db = drop_columns_ensi_skills(enski_skills_db)
enski_skills_db.head(5)
# Out:
#                                    skill_description              skill_id  \
# 1  \nDefined by Microsoft for use in recent versi...  KS126XS6CQCFGC3NG79X
# 2                                                NaN  ES50D03AC9CFC1A0BC93
# 3  The .NET Framework is a software framework dev...  KS1200B62W5ZF38RJ7TD
# 4  Microsoft started development on the .NET Fram...  KS126XW78QJCF4TRV2X7
# 5  The .NET Framework is a software framework dev...  KS126XY68BNKXSBSLPYS
#
#                                              infoUrl  isLanguage  isSoftware  \
# 1  https://skills.emsidata.com/skills/KS126XS6CQC...       False        True
# 2  https://skills.emsidata.com/skills/ES50D03AC9C...       False       False
# 3  https://skills.emsidata.com/skills/KS1200B62W5...       False        True
# 4  https://skills.emsidata.com/skills/KS126XW78QJ...       False        True
# 5  https://skills.emsidata.com/skills/KS126XY68BN...       False        True
#
#          skill_name    skill_type_name     skill_category_name  \
# 1   .NET Assemblies  Specialized Skill  Information Technology
# 2  .NET Development  Specialized Skill  Information Technology
# 3    .NET Framework  Specialized Skill  Information Technology
# 4  .NET Framework 1  Specialized Skill  Information Technology
# 5  .NET Framework 3  Specialized Skill  Information Technology
#
#         skill_subcategory_name
# 1  Microsoft Development Tools
# 2  Microsoft Development Tools
# 3  Microsoft Development Tools
# 4  Microsoft Development Tools
# 5  Microsoft Development Tools

# %%
found_skills.head(5) # Prints the first 5 rows of the found_skills dataframe
# Out:
#    id_text              skill_id          skill_name  \
# 0        2  KS121Z26S4VJLQ1WXN21    customer service
# 1        1  KS120PL63HT8CXQ6LPDR      asset managers
# 2        1  KS120PL63HT8CXQ6LPDR       asset manager
# 3        2  KS120XP636CB5432F5TP  telecommunications
# 4        2  KS122556LMQ829GZCCRV      communications
#
#                                                 text
# 0  as a listed company with around million custom...
# 1  swiss life asset managers is the most successf...
# 2  swiss life asset managers is the most successf...
# 3  as a listed company with around million custom...
# 4  as a listed company with around million custom...

# %%
# This code merges two dataframes based on the common column 'skill_id'.
# The dataframes are:
# 1) found_skills - a dataframe of skills that were found in a job posting
# 2) enski_skills_db - a dataframe of skills in the Enki Skills Database
# The merge is an 'inner' merge, meaning that only the skills that are in both dataframes will be merged together.
# The resulting dataframe is found_skills_for_tableau.
# The .head(5) command just shows the first 5 rows of the resulting dataframe.

found_skills_for_tableau = pd.merge(found_skills, enski_skills_db, how='inner',on='skill_id')
found_skills_for_tableau.head(5)
# Out:
#    id_text              skill_id        skill_name_x  \
# 0        2  KS121Z26S4VJLQ1WXN21    customer service
# 1        1  KS120PL63HT8CXQ6LPDR      asset managers
# 2        1  KS120PL63HT8CXQ6LPDR       asset manager
# 3        2  KS120XP636CB5432F5TP  telecommunications
# 4        2  KS122556LMQ829GZCCRV      communications
#
#                                                 text  \
# 0  as a listed company with around million custom...
# 1  swiss life asset managers is the most successf...
# 2  swiss life asset managers is the most successf...
# 3  as a listed company with around million custom...
# 4  as a listed company with around million custom...
#
#                                    skill_description  \
# 0  Customer service is the provision of service t...
# 1                                                NaN
# 2                                                NaN
# 3  Telecommunication is the transmission of infor...
# 4  Communication is the act of developing meaning...
#
#                                              infoUrl  isLanguage  isSoftware  \
# 0  https://skills.emsidata.com/skills/KS121Z26S4V...       False       False
# 1  https://skills.emsidata.com/skills/KS120PL63HT...       False       False
# 2  https://skills.emsidata.com/skills/KS120PL63HT...       False       False
# 3  https://skills.emsidata.com/skills/KS120XP636C...       False       False
# 4  https://skills.emsidata.com/skills/KS122556LMQ...       False       False
#
#          skill_name_y    skill_type_name              skill_category_name  \
# 0    Customer Service       Common Skill      Customer and Client Support
# 1    Asset Management  Specialized Skill                         Business
# 2    Asset Management  Specialized Skill                         Business
# 3  Telecommunications  Specialized Skill           Information Technology
# 4      Communications       Common Skill  Physical and Inherent Abilities
#
#   skill_subcategory_name
# 0       Customer Service
# 1    Business Operations
# 2    Business Operations
# 3     Telecommunications
# 4          Communication

# %%
# Drops duplicate rows
found_skills.drop_duplicates(subset=['id_text','skill_id'], keep='first', inplace=True)

# %%
# Saves the dataframe as an Excel file


found_skills_for_tableau.to_excel('Master/04_Analysis/04_01_custom_analysis/04_01_tableau_data/14_tableau_analysis_ensi_skills_lost.xlsx', index=False)
